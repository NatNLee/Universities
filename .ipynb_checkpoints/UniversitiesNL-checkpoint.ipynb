# %%
import numpy as np 
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('~/GalvanizeJupyter/universities.csv')

# %%
df
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %%
df.describe()
# Out:
#                Size
# count    2829.00000
# mean     4374.88123
# std      9256.38326
# min         4.00000
# 25%       493.00000
# 50%      1478.00000
# 75%      4064.00000
# max    301323.00000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2907 entries, 0 to 2906
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     2907 non-null   object
#  1   address  2907 non-null   object
#  2   Website  2822 non-null   object
#  3   Type     2907 non-null   object
#  4   Size     2829 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 113.7+ KB

# %%
df.columns
# Out:
# Index(['name', 'address', 'Website', 'Type', 'Size'], dtype='object')

# %%
df.shape
# Out:
# (2907, 5)

# %%
df.iloc[3]
# Out:
# name                                         Academy College
# address    1101 E. 78th Street, Suite 100, Minneapolis, M...
# Website                               www.academycollege.edu
# Type       4-year, primarily associate's, Private for-profit
# Size                                                     165
# Name: 3, dtype: object

# %% [markdown]
# ## find both the mean and median size by each university type (as given in the dataframe), ordered by average size in ascending order.

# %%
df.groupby('Type')['Size'].mean().sort_values()
# Out:
# Type
# 4-year, primarily associate's, Private for-profit          934.380597
# 4-year, primarily associate's, Private not-for-profit     1129.413793
# 4-year, Private not-for-profit                            2399.885696
# 4-year, Private for-profit                                3504.501859
# 4-year, primarily associate's, Public                     6889.366197
# 4-year, Public                                           11478.913765
# Name: Size, dtype: float64

# %%
df.groupby('Type')['Size'].median().sort_values()
# Out:
# Type
# 4-year, primarily associate's, Private for-profit         564.5
# 4-year, Private for-profit                                730.0
# 4-year, primarily associate's, Private not-for-profit     768.0
# 4-year, Private not-for-profit                           1206.0
# 4-year, primarily associate's, Public                    3558.0
# 4-year, Public                                           7669.0
# Name: Size, dtype: float64

# %% [markdown]
# ## Make new columns  in the dataframe from existing data for the following attributes:
# #City
# #State
# #ZipCode
# #Private or Public
# #for-profit or not-for-profit
# #primarily associate's (1 for Yes, 0 for No)

# %% [markdown]
# #city column

# %%
#df.address.str.split(",", n=1,expand=True,)

# %%
#create city column test 1
#city=df.address.str.split(",").str[1]
#df['city']=city

# %%
#create city column test 2 final
c=df.address.str.split(",").str[-2]
df['city']=c
df
#city is between two commas second from the right?
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %% [markdown]
# #state column

# %%
#create state column test 1
#state=df.address.str.split(",").str[1]
#df['state']=state

#df.address.str.split(",")
#s=df.address.str.split(",", n=1,expand=True,)
#s=df.address.str.split(",").str[2]
#s=df.address.str.split(" ").str[4]
#s

# %%
#create state column test 2
#s1=df.address.str.split(",").str[2]
#s2=s1.str.split(" ").str[1]
#df['state']=s2
#df

# %%
# create state column test 3 
#s1=df.address.str.split(" ").str[-2]
#state is between 2 spaces from the right?
#s2=s1.str.split(",").str[-1]
#df['state']=s1
#df

# %%
#create state column test 4 final
s1=df.address.str.split(",").str[-1]
s2=s1.str.rsplit(" ",n=1, expand=True)
s2.head(30)
df['state']=s2[0]
df.head(30)
# Out:
#                                                  name  \
# 0             A T Still University of Health Sciences
# 1                        Abilene Christian University
# 2                Abraham Baldwin Agricultural College
# 3                                     Academy College
# 4                Academy for Five Element Acupuncture
# 5                           Academy of Art University
# 6      Academy of Chinese Culture and Health Sciences
# 7                        Academy of Oriental Medicine
# 8                               Academy of Vocal Arts
# 9   Acupuncture and Integrative Medicine College-B...
# 10                    Acupuncture and Massage College
# 11                                Adams State College
# 12                                 Adelphi University
# 13                              Adler Graduate School
# 14            Adler School of Professional Psychology
# 15                                     Adrian College
# ...

# %%
df.state.head(30)
# Out:
# 0          Missouri
# 1             Texas
# 2           Georgia
# 3         Minnesota
# 4           Florida
# 5        California
# 6        California
# 7             Texas
# 8      Pennsylvania
# 9        California
# 10          Florida
# 11         Colorado
# 12         New York
# 13        Minnesota
# 14         Illinois
# 15         Michigan
# 16          Georgia
# 17          Florida
# 18             Iowa
# 19             Ohio
# 20          Alabama
# 21          Alabama
# 22           Alaska
# 23         New York
# 24         New York
# 25         New York
# 26          Georgia
# 27      Connecticut
# 28         Michigan
# 29     Pennsylvania
# Name: state, dtype: object

# %% [markdown]
# #zipcode column

# %%
#create zipcode test 1
#s1
#z=s1.str.split(" ").str[2]
#z
#df['zipcode']=z
#df

# %%
#create zipcode test 2 final

z=df.address.str.split(" ").str[-1]
df['zipcode']=z
df
#zipcode is one space from the right
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %% [markdown]
# #private or public column

# %%
#create private or public column test 1
#df.iloc[:,3].head(10)
#df.iloc[:,3].tail(10)
#df.Type.str.split(" ").str[-1]

# %%
#create private or public column test 2 final

df['Private_or_Public'] = ["Private" if x ==True else "Public" for x in df.Type.str.contains('Private')]
df
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %% [markdown]
# #for profit or not for profit column

# %%
#create for profit or not for profit column test 1
#df.iloc[:,3].head(30)
#df['Profit'] = ["not-for-profit" if x ==True else None for x in df.Type.str.contains('not-for-profit')]
#df
#df['Profit'] = ["not-for-profit" if x ==True else None for x in df.Type.str.contains('not-for-profit')]
#df
#df['Profit'] = ["for-profit" if x ==True else None for x in df.Type.str.contains('for-profit')]
#above doesnt work because it overwrites not for profit since not for profit contains the words for profit

# %%
#create profit columnn test 2 final
def conditions(p):
    if 'not-for-profit' in p.Type:
        return "not-for-profit"
    elif ' for-profit' in p.Type:    
        return "for-profit"
    else:
        pass

# %%
df['Profit'] = df.apply(conditions, axis=1)
df
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %% [markdown]
# #primarily assc column

# %%
#primarily assc column

df['primarily_associates'] = [1 if x ==True else 0 for x in df.Type.str.contains('primarily associate')]
df
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %% [markdown]
# ## Using the new columns you've made above (and excluding the original type column), find both the mean and median size of each university by State, by Private or Public, and by whether the university is primarily associate's or not.

# %%
df.groupby(['state','Private_or_Public','primarily_associates'])['Size'].mean()
# Out:
# state       Private_or_Public  primarily_associates
#  Alabama    Private            0                        2629.750000
#                                1                        1078.250000
#             Public             0                       11537.928571
#  Alaska     Private            0                         803.000000
#                                1                         747.000000
#                                                            ...
#  Wisconsin  Private            1                         963.333333
#             Public             0                       12603.357143
#  Wyoming    Private            0                          12.000000
#                                1                         146.000000
#             Public             0                       12067.000000
# Name: Size, Length: 178, dtype: float64

# %%
df.groupby(['state','Private_or_Public','primarily_associates'])['Size'].median()
# Out:
# state       Private_or_Public  primarily_associates
#  Alabama    Private            0                        1065.0
#                                1                         550.5
#             Public             0                        7317.0
#  Alaska     Private            0                         803.0
#                                1                         747.0
#                                                         ...
#  Wisconsin  Private            1                         921.5
#             Public             0                        9521.5
#  Wyoming    Private            0                          12.0
#                                1                         146.0
#             Public             0                       12067.0
# Name: Size, Length: 178, dtype: float64

# %%
df.groupby('state')['Size'].mean()
# Out:
# state
#  Alabama                  5303.619048
#  Alaska                   5945.600000
#  American Samoa           1806.000000
#  Arizona                 12079.121951
#  Arkansas                 3967.692308
#  California               4347.544681
#  Colorado                 4853.040816
#  Connecticut              3861.323529
#  Delaware                 6325.000000
#  District of Columbia     7423.588235
#  Florida                  5649.072000
#  Georgia                  4305.129870
#  Guam                     1768.000000
#  Hawaii                   3375.153846
#  Idaho                    6059.727273
#  Illinois                 4187.118644
#  Indiana                  4182.381579
#  Iowa                     4223.212766
#  Kansas                   3489.400000
#  Kentucky                 3736.295455
#  Louisiana                5419.968750
#  Maine                    2562.450000
#  Maryland                 5188.487805
#  Massachusetts            3836.343434
# ...

# %%
df.groupby('state')['Size'].median()
# Out:
# state
#  Alabama                 1693.0
#  Alaska                  2954.0
#  American Samoa          1806.0
#  Arizona                 1059.0
#  Arkansas                1755.0
#  California               918.0
#  Colorado                1308.0
#  Connecticut             1957.0
#  Delaware                2883.5
#  District of Columbia    1389.0
#  Florida                 1184.0
#  Georgia                 1987.0
#  Guam                    1768.0
#  Hawaii                  1140.0
#  Idaho                   1939.0
#  Illinois                1277.0
#  Indiana                 1286.0
#  Iowa                    1361.0
#  Kansas                   634.0
#  Kentucky                1485.0
#  Louisiana               3048.5
#  Maine                   1589.0
#  Maryland                2079.0
#  Massachusetts           1697.0
#  Michigan                2440.0
#  Minnesota                999.5
#  Mississippi             2492.0
#  Missouri                 889.0
#  Montana                 1313.0
# ...

# %%
df.groupby('Private_or_Public')['Size'].mean()
# Out:
# Private_or_Public
# Private     2304.226914
# Public     10995.445104
# Name: Size, dtype: float64

# %%
df.groupby('Private_or_Public')['Size'].median()
# Out:
# Private_or_Public
# Private     948.0
# Public     7081.0
# Name: Size, dtype: float64

# %%
df.groupby('primarily_associates')['Size'].mean()
# Out:
# primarily_associates
# 0    4801.798169
# 1    1966.708920
# Name: Size, dtype: float64

# %%
df.groupby('primarily_associates')['Size'].median()
# Out:
# primarily_associates
# 0    1727.0
# 1     716.0
# Name: Size, dtype: float64

# %% [markdown]
# ## Use the tools you've learned to compute at **least** one other aggregate from the dataset

# %%
#mask=df.Private_or_Public
#df.Private_or_Public.count()

df[df['Private_or_Public']=="Public"].name.count()
# Out:
# 689

# %% [markdown]
# ## Save the updated dataframe as a csv  (using the pandas to_csv method) and commit your files, and push up to github.
