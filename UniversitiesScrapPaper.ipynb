# %%
import numpy as np 
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('~/GalvanizeJupyter/universities.csv')

# %%
df
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %%
s1=df.address.str.split(" ").str[-2]
s2=s1.str.split(",").str[-1]

# %%
s2
# Out:
# 0            Missouri
# 1               Texas
# 2             Georgia
# 3           Minnesota
# 4             Florida
#             ...
# 2902       California
# 2903         Nebraska
# 2904     Pennsylvania
# 2905             Ohio
# 2906    Massachusetts
# Name: address, Length: 2907, dtype: object

# %%
df.address.str.split(" ").str[-2]
# Out:
# 0            Missouri
# 1               Texas
# 2             Georgia
# 3           Minnesota
# 4             Florida
#             ...
# 2902       California
# 2903         Nebraska
# 2904     Pennsylvania
# 2905             Ohio
# 2906    Massachusetts
# Name: address, Length: 2907, dtype: object

# %%
df.address.str.split(" ").str[-1]
# Out:
# 0            63501
# 1            79699
# 2       31793-2601
# 3       55420-1554
# 4            32601
#            ...
# 2902         90066
# 2903    68467-2699
# 2904    17403-3651
# 2905    44555-0001
# 2906         01835
# Name: address, Length: 2907, dtype: object

# %%
c=df.address.str.split(" ").str[-3]
c
# Out:
# 0        Kirksville,
# 1           Abilene,
# 2            Tifton,
# 3       Minneapolis,
# 4       Gainesville,
#             ...
# 2902        Angeles,
# 2903           York,
# 2904           York,
# 2905     Youngstown,
# 2906      Haverhill,
# Name: address, Length: 2907, dtype: object

# %%
c.str.split(",").str[-2]
# Out:
# 0        Kirksville
# 1           Abilene
# 2            Tifton
# 3       Minneapolis
# 4       Gainesville
#            ...
# 2902        Angeles
# 2903           York
# 2904           York
# 2905     Youngstown
# 2906      Haverhill
# Name: address, Length: 2907, dtype: object

# %%
c=df.address.str.split(",").str[-2]
# Out:
# 0         Kirksville
# 1            Abilene
# 2             Tifton
# 3        Minneapolis
# 4        Gainesville
#             ...
# 2902     Los Angeles
# 2903            York
# 2904            York
# 2905      Youngstown
# 2906       Haverhill
# Name: address, Length: 2907, dtype: object

# %%
df.Type.str.split(",",expand = True,)
# Out:
#            0                        1                    2
# 0     4-year   Private not-for-profit                 None
# 1     4-year   Private not-for-profit                 None
# 2     4-year    primarily associate's               Public
# 3     4-year    primarily associate's   Private for-profit
# 4     4-year   Private not-for-profit                 None
# ...      ...                      ...                  ...
# 2902  4-year   Private not-for-profit                 None
# 2903  4-year   Private not-for-profit                 None
# 2904  4-year   Private not-for-profit                 None
# 2905  4-year                   Public                 None
# 2906  4-year   Private not-for-profit                 None
#
# [2907 rows x 3 columns]

# %%
df.Type.str.split(" ",expand = True,)
# Out:
#             0          1               2        3           4
# 0     4-year,    Private  not-for-profit     None        None
# 1     4-year,    Private  not-for-profit     None        None
# 2     4-year,  primarily    associate's,   Public        None
# 3     4-year,  primarily    associate's,  Private  for-profit
# 4     4-year,    Private  not-for-profit     None        None
# ...       ...        ...             ...      ...         ...
# 2902  4-year,    Private  not-for-profit     None        None
# 2903  4-year,    Private  not-for-profit     None        None
# 2904  4-year,    Private  not-for-profit     None        None
# 2905  4-year,     Public            None     None        None
# 2906  4-year,    Private  not-for-profit     None        None
#
# [2907 rows x 5 columns]

# %%
pop=df.Type.str.contains('Private')

# %%
df['Private_or_Public'] = ["Private" if x ==True else "Public" for x in df.Type.str.contains('Private')] 
  
# Print the DataFrame 
df
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %%
df.iloc[:,3].head(30)
# Out:
# 0                        4-year, Private not-for-profit
# 1                        4-year, Private not-for-profit
# 2                 4-year, primarily associate's, Public
# 3     4-year, primarily associate's, Private for-profit
# 4                        4-year, Private not-for-profit
# 5                            4-year, Private for-profit
# 6                        4-year, Private not-for-profit
# 7                            4-year, Private for-profit
# 8                        4-year, Private not-for-profit
# 9                        4-year, Private not-for-profit
# 10    4-year, primarily associate's, Private for-profit
# 11                                       4-year, Public
# 12                       4-year, Private not-for-profit
# 13                       4-year, Private not-for-profit
# 14                       4-year, Private not-for-profit
# 15                       4-year, Private not-for-profit
# 16                       4-year, Private not-for-profit
# ...

# %%
df.Type.str.contains('not-for-profit')
#df['Private_or_Public'] = ["Private" if x ==True else "Public" for x in df.Type.str.contains('Private')]
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4        True
#         ...
# 2902     True
# 2903     True
# 2904     True
# 2905    False
# 2906     True
# Name: Type, Length: 2907, dtype: bool

# %%
df.Type.str.contains('for-profit')
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 2902     True
# 2903     True
# 2904     True
# 2905    False
# 2906     True
# Name: Type, Length: 2907, dtype: bool

# %%
df['Profit'] = ["not-for-profit" if x ==True in df.Type.str.contains('not-for-profit') if "for-profit" x==True in df.Type.str.contains('for-profit') else Null]
# Out:
#   File "<ipython-input-54-5ba7e9aa3ffd>", line 1
#     df['Profit'] = ["not-for-profit" if x ==True in df.Type.str.contains('not-for-profit') if "for-profit" x==True in df.Type.str.contains('for-profit') else Null]
#                                                                                             ^
# SyntaxError: invalid syntax

# %%
df['Profit']=None

# %%
df
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %%
df['Profit'] = ["not-for-profit" if x ==True else None for x in df.Type.str.contains('not-for-profit')]
df
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %%
#df['Private_or_Public'] = ["Private" if x ==True else "Public" for x in df.Type.str.contains('Private')]
df

# %%
df['Profit'] = ["for-profit" if x ==True else None for x in df.Type.str.contains('for-profit')]

# %%
df
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %%
df.head(30)
# Out:
#                                                  name  \
# 0             A T Still University of Health Sciences
# 1                        Abilene Christian University
# 2                Abraham Baldwin Agricultural College
# 3                                     Academy College
# 4                Academy for Five Element Acupuncture
# 5                           Academy of Art University
# 6      Academy of Chinese Culture and Health Sciences
# 7                        Academy of Oriental Medicine
# 8                               Academy of Vocal Arts
# 9   Acupuncture and Integrative Medicine College-B...
# 10                    Acupuncture and Massage College
# 11                                Adams State College
# 12                                 Adelphi University
# 13                              Adler Graduate School
# 14            Adler School of Professional Psychology
# 15                                     Adrian College
# ...

# %%
df.Type.str.contains('not')
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4        True
#         ...
# 2902     True
# 2903     True
# 2904     True
# 2905    False
# 2906     True
# Name: Type, Length: 2907, dtype: bool

# %%
df['Profit'] = ["for-profit" if x ==False else 0 for x in df.Type.str.contains('not')]
# Out:
#   File "<ipython-input-89-180a3e0cdad7>", line 1
#     df['Profit'] = ["for-profit" if x ==False else return pass for x in df.Type.str.contains('not')]
#                                                         ^
# SyntaxError: invalid syntax

# %%
df
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %%
def conditions(p):
    if 'not-for-profit' in p.Type:
        return "not-for-profit"
    elif ' for-profit' in p.Type:    
        return "for-profit"
    else:
        pass
    
    #df.Type.str.contains('not-for-profit')
    
    #df['Profit'] = ["not-for-profit" if x ==True else None for x in df.Type.str.contains('not-for-profit')]

# %%
#def conditions(p):
    #if df.Type.str.contains('not-for-profit'):
        #return "not-for-profit"
   # elif df.Type.str.contains('not'):    
   #     return "for-profit"
   # else:
    #    pass

# %%
df['Profit'] = df.apply(conditions, axis=1)
df
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %%
df.loc[df.Type.str.contains(' for-profit') & df.Type.str.contains('Private')]
# Out:
#                                                    name  \
# 3                                       Academy College
# 5                             Academy of Art University
# 7                          Academy of Oriental Medicine
# 10                      Acupuncture and Massage College
# 17    AI Miami International University of Art and D...
# ...                                                 ...
# 2825                       Westwood College-Los Angeles
# 2826                         Westwood College-Northlake
# 2827                    Westwood College-O'Hare Airport
# 2828                        Westwood College-River Oaks
# 2829                         Westwood College-South Bay
#
#                                                 address  \
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# 5     79 New Montgomery, San Francisco, California 9...
# 7       2700 W Anderson Ln Ste 204, Austin, Texas 78757
# 10          10506 N Kendall Drive, Miami, Florida 33176
# ...

# %%
#primarily assc

df['primarily_associates'] = [1 if x ==True else 0 for x in df.Type.str.contains('primarily associate')]

# %%
df
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %%
s1=df.address.str.split(" ").str[-2]
#state is between 2 spaces from the right?
s2=s1.str.split(",").str[-1]
df['state']=s2
df
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %%
df.groupby('state')['Size'].median()
# Out:
# state
# Alabama          1693.0
# Alaska           2954.0
# Arizona          1059.0
# Arkansas         1755.0
# California        918.0
# Carolina         1499.5
# Colorado         1308.0
# Columbia         1389.0
# Connecticut      1957.0
# Dakota           1180.0
# Delaware         2883.5
# Florida          1184.0
# Georgia          1987.0
# Guam             1768.0
# Hampshire        1542.0
# Hawaii           1140.0
# Idaho            1939.0
# Illinois         1277.0
# Indiana          1286.0
# Iowa             1361.0
# Island           4609.0
# Islands          2393.0
# Jersey           3465.0
# Kansas            634.0
# Kentucky         1485.0
# Louisiana        3048.5
# Maine            1589.0
# Marianas          791.0
# Maryland         2079.0
# Massachusetts    1697.0
# Mexico            618.0
# Michigan         2440.0
# Minnesota         999.5
# Mississippi      2492.0
# Missouri          889.0
# Montana          1313.0
# Nebraska          904.0
# Nevada           1301.0
# ...

# %%
c1=df.address.str.split(",").str[-1].head(30)
c1
#c2=c1.str.extract('([A-Za-z]+)')
#c2
# Out:
# 0               Missouri 63501
# 1                  Texas 79699
# 2           Georgia 31793-2601
# 3         Minnesota 55420-1554
# 4                Florida 32601
# 5             California 94105
# 6             California 94612
# 7                  Texas 78757
# 8      Pennsylvania 19103-6685
# 9             California 94704
# 10               Florida 33176
# 11              Colorado 81102
# 12         New York 11530-0701
# 13             Minnesota 55423
# 14              Illinois 60601
# 15         Michigan 49221-2575
# 16          Georgia 30030-3797
# 17          Florida 33132-1418
# 18             Iowa 50321-1799
# 19             Ohio 45433-7765
# 20               Alabama 35762
# 21          Alabama 36101-0271
# 22                Alaska 99508
# 23         New York 12208-3492
# 24              New York 12208
# 25         New York 12208-0000
# 26               Georgia 31705
# 27      Connecticut 06511-1189
# 28              Michigan 49224
# 29     Pennsylvania 19612-5234
# ...

# %%
c2=c1.str.extract('([A-Za-z]+)')
c1
# Out:
# 0               Missouri 63501
# 1                  Texas 79699
# 2           Georgia 31793-2601
# 3         Minnesota 55420-1554
# 4                Florida 32601
# 5             California 94105
# 6             California 94612
# 7                  Texas 78757
# 8      Pennsylvania 19103-6685
# 9             California 94704
# 10               Florida 33176
# 11              Colorado 81102
# 12         New York 11530-0701
# 13             Minnesota 55423
# 14              Illinois 60601
# 15         Michigan 49221-2575
# 16          Georgia 30030-3797
# 17          Florida 33132-1418
# 18             Iowa 50321-1799
# 19             Ohio 45433-7765
# 20               Alabama 35762
# 21          Alabama 36101-0271
# 22                Alaska 99508
# 23         New York 12208-3492
# 24              New York 12208
# 25         New York 12208-0000
# 26               Georgia 31705
# 27      Connecticut 06511-1189
# 28              Michigan 49224
# 29     Pennsylvania 19612-5234
# ...

# %%
df.address.str.extract('([A-Za-z]+)')
# Out:
#             0
# 0           W
# 1      Campus
# 2       Moore
# 3           E
# 4          SE
# ...       ...
# 2902        W
# 2903        E
# 2904  Country
# 2905      One
# 2906    South
#
# [2907 rows x 1 columns]

# %%
df.head(30)
# Out:
#                                                  name  \
# 0             A T Still University of Health Sciences
# 1                        Abilene Christian University
# 2                Abraham Baldwin Agricultural College
# 3                                     Academy College
# 4                Academy for Five Element Acupuncture
# 5                           Academy of Art University
# 6      Academy of Chinese Culture and Health Sciences
# 7                        Academy of Oriental Medicine
# 8                               Academy of Vocal Arts
# 9   Acupuncture and Integrative Medicine College-B...
# 10                    Acupuncture and Massage College
# 11                                Adams State College
# 12                                 Adelphi University
# 13                              Adler Graduate School
# 14            Adler School of Professional Psychology
# 15                                     Adrian College
# ...

# %%
city=df.address.str.split(",").str[-2]
df['city']=city

# %%
df.head(30)
# Out:
#                                                  name  \
# 0             A T Still University of Health Sciences
# 1                        Abilene Christian University
# 2                Abraham Baldwin Agricultural College
# 3                                     Academy College
# 4                Academy for Five Element Acupuncture
# 5                           Academy of Art University
# 6      Academy of Chinese Culture and Health Sciences
# 7                        Academy of Oriental Medicine
# 8                               Academy of Vocal Arts
# 9   Acupuncture and Integrative Medicine College-B...
# 10                    Acupuncture and Massage College
# 11                                Adams State College
# 12                                 Adelphi University
# 13                              Adler Graduate School
# 14            Adler School of Professional Psychology
# 15                                     Adrian College
# ...

# %%
c1=df.address.str.split(",").str[-1].head(30)
c2=c1.str.extract('([A-Za-z]+)')
c1
# Out:
# 0               Missouri 63501
# 1                  Texas 79699
# 2           Georgia 31793-2601
# 3         Minnesota 55420-1554
# 4                Florida 32601
# 5             California 94105
# 6             California 94612
# 7                  Texas 78757
# 8      Pennsylvania 19103-6685
# 9             California 94704
# 10               Florida 33176
# 11              Colorado 81102
# 12         New York 11530-0701
# 13             Minnesota 55423
# 14              Illinois 60601
# 15         Michigan 49221-2575
# 16          Georgia 30030-3797
# 17          Florida 33132-1418
# 18             Iowa 50321-1799
# 19             Ohio 45433-7765
# 20               Alabama 35762
# 21          Alabama 36101-0271
# 22                Alaska 99508
# 23         New York 12208-3492
# 24              New York 12208
# 25         New York 12208-0000
# 26               Georgia 31705
# 27      Connecticut 06511-1189
# 28              Michigan 49224
# 29     Pennsylvania 19612-5234
# ...

# %%
c2
# Out:
#                0
# 0       Missouri
# 1          Texas
# 2        Georgia
# 3      Minnesota
# 4        Florida
# 5     California
# 6     California
# 7          Texas
# 8   Pennsylvania
# 9     California
# 10       Florida
# 11      Colorado
# 12           New
# 13     Minnesota
# 14      Illinois
# 15      Michigan
# 16       Georgia
# 17       Florida
# 18          Iowa
# 19          Ohio
# 20       Alabama
# 21       Alabama
# 22        Alaska
# 23           New
# 24           New
# 25           New
# 26       Georgia
# 27   Connecticut
# 28      Michigan
# 29  Pennsylvania

# %%
for char in c1:
    if char.isaplha():
        str.extract()
# Out:
#   File "<ipython-input-170-6cdbdbb53ae2>", line 1
#     for state in c1
#                    ^
# SyntaxError: invalid syntax

# %%
c3=df.address.str.split(",").str[-1]

c4 = []

for char in c3.str.split():
    c3.str.extract('([A-Za-z]+)')
    c4.append(char)

# %%
c4
# Out:
# [['Missouri', '63501'],
#  ['Texas', '79699'],
#  ['Georgia', '31793-2601'],
#  ['Minnesota', '55420-1554'],
#  ['Florida', '32601'],
#  ['California', '94105'],
#  ['California', '94612'],
#  ['Texas', '78757'],
#  ['Pennsylvania', '19103-6685'],
#  ['California', '94704'],
#  ['Florida', '33176'],
#  ['Colorado', '81102'],
#  ['New', 'York', '11530-0701'],
#  ['Minnesota', '55423'],
#  ['Illinois', '60601'],
#  ['Michigan', '49221-2575'],
#  ['Georgia', '30030-3797'],
#  ['Florida', '33132-1418'],
#  ['Iowa', '50321-1799'],
#  ['Ohio', '45433-7765'],
#  ['Alabama', '35762'],
#  ['Alabama', '36101-0271'],
#  ['Alaska', '99508'],
#  ['New', 'York', '12208-3492'],
#  ['New', 'York', '12208'],
#  ['New', 'York', '12208-0000'],
#  ['Georgia', '31705'],
#  ['Connecticut', '06511-1189'],
#  ['Michigan', '49224'],
#  ['Pennsylvania', '19612-5234'],
#  ['Mississippi', '39096-7500'],
#  ['West', 'Virginia', '26416-2035'],
#  ['New', 'York', '14802-1205'],
#  ['Kentucky', '41844'],
# ...

# %%
s1=df.address.str.split(",").str[-1]
s2=s1.str.rsplit(" ",n=1, expand=True)
s2.head(30)
df['state']=s2[0]
df.head(30)
# Out:
#                                                  name  \
# 0             A T Still University of Health Sciences
# 1                        Abilene Christian University
# 2                Abraham Baldwin Agricultural College
# 3                                     Academy College
# 4                Academy for Five Element Acupuncture
# 5                           Academy of Art University
# 6      Academy of Chinese Culture and Health Sciences
# 7                        Academy of Oriental Medicine
# 8                               Academy of Vocal Arts
# 9   Acupuncture and Integrative Medicine College-B...
# 10                    Acupuncture and Massage College
# 11                                Adams State College
# 12                                 Adelphi University
# 13                              Adler Graduate School
# 14            Adler School of Professional Psychology
# 15                                     Adrian College
# ...

# %%
c1.str.split(" ", expand=True).str[-1]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-199-e09a0ba4b221> in <module>
# ----> 1 c1.str.split(" ", expand=True).str[-1]
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'str'

# %%
# Out:
# 0          63501
# 1          79699
# 2     31793-2601
# 3     55420-1554
# 4          32601
# 5          94105
# 6          94612
# 7          78757
# 8     19103-6685
# 9          94704
# 10         33176
# 11         81102
# 12    11530-0701
# 13         55423
# 14         60601
# 15    49221-2575
# 16    30030-3797
# 17    33132-1418
# 18    50321-1799
# 19    45433-7765
# 20         35762
# 21    36101-0271
# 22         99508
# 23    12208-3492
# 24         12208
# 25    12208-0000
# 26         31705
# 27    06511-1189
# 28         49224
# 29    19612-5234
# Name: address, dtype: object

# %%
c1.str.split(",", expand=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-202-b2530c974cd3> in <module>
# ----> 1 c6=c1.str.split(",", expand=True)
#       2 c6
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'str'

# %%
c1=df.address.str.split(",")
c2=c1[2].str.rsplit(" ",n=1, expand=True)
c2.head(30)
c1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-227-cd5ed7a68917> in <module>
# ----> 1 c1=df.address.str.split(",")[-1]
#       2 c2=c1[2].str.rsplit(" ",n=1, expand=True)
#       3 c2.head(30)
#       4 c1
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4403         k = self._convert_scalar_indexer(k, kind="getitem")
#    4404         try:
# -> 4405             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4406         except KeyError as e1:
# ...

# %%
c1
# Out:
#                                   0             1                         2  \
# 0                   800 W Jefferson    Kirksville            Missouri 63501
# 1                 1600 Campus Court       Abilene               Texas 79699
# 2                    2802 Moore Hwy        Tifton        Georgia 31793-2601
# 3               1101 E. 78th Street     Suite 100               Minneapolis
# 4                    305 SE 2nd Ave   Gainesville             Florida 32601
# ...                             ...           ...                       ...
# 2902  13315 W. Washington Boulevard   Los Angeles          California 90066
# 2903                  1125 E 8th St          York       Nebraska 68467-2699
# 2904                Country Club Rd          York   Pennsylvania 17403-3651
# 2905           One University Plaza    Youngstown           Ohio 44555-0001
# 2906          320 South Main Street     Haverhill       Massachusetts 01835
#
#                           3     4     5
# ...

# %%
c2=c1.str.split(" ").str[1]
c.head(30)
# Out:
# 0            Missouri
# 1               Texas
# 2             Georgia
# 3           Minnesota
# 4             Florida
#             ...
# 2902       California
# 2903         Nebraska
# 2904     Pennsylvania
# 2905             Ohio
# 2906    Massachusetts
# Name: address, Length: 2907, dtype: object

# %%
c2.head(30)
# Out:
# 0         Missouri
# 1            Texas
# 2          Georgia
# 3        Minnesota
# 4          Florida
# 5       California
# 6       California
# 7            Texas
# 8     Pennsylvania
# 9       California
# 10         Florida
# 11        Colorado
# 12             New
# 13       Minnesota
# 14        Illinois
# 15        Michigan
# 16         Georgia
# 17         Florida
# 18            Iowa
# 19            Ohio
# 20         Alabama
# 21         Alabama
# 22          Alaska
# 23             New
# 24             New
# 25             New
# 26         Georgia
# 27     Connecticut
# 28        Michigan
# 29    Pennsylvania
# Name: address, dtype: object

# %%
df
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...
